# %%
# Importing Libraries
import pandas as pd

# Specify the actual path to your CSV file
csv_file_path = r'C:\Users\User\Desktop\sample\October 8 to October 14\Analyze Data\merged-files.csv'

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(csv_file_path)

# Display the DataFrame
df.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13956\38275746.py:8: DtypeWarning: Columns (6,7,8,12,16,17,18,19,20,21,27,28,29,30,33,34,35,36,37,38,40,41,42,43,44,48,49,55,57,58,61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path)
#   Date (charge) Category (charge)           Fee (charge)  \
# 0    2023-10-09             order  Fulfillment - Postage
# 1    2023-10-09             order  Fulfillment - Postage
# 2    2023-10-09             order  Fulfillment - Postage
# 3    2023-10-10             order  Fulfillment - Postage
# 4    2023-10-10             order  Fulfillment - Postage
#
#            Type (charge)  Label (charge)  \
# 0  shipping_label_charge  shipping label
# 1  shipping_label_charge  shipping label
# 2  shipping_label_charge  shipping label
# 3  shipping_label_charge  shipping label
# 4  shipping_label_charge  shipping label
#
#                                 Description (charge) Unit rate (charge)  \
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv(r'C:\Users\User\Desktop\sample\October 8 to October 14\Analyze Data\merged-files.csv', low_memory=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85108 entries, 0 to 85107
# Data columns (total 63 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Date (charge)                                 54512 non-null  object
#  1   Category (charge)                             85108 non-null  object
#  2   Fee (charge)                                  85108 non-null  object
#  3   Type (charge)                                 85108 non-null  object
#  4   Label (charge)                                85108 non-null  object
#  5   Description (charge)                          85108 non-null  object
#  6   Unit rate (charge)                            85108 non-null  object
#  7   Quantity (charge)                             85108 non-null  object
#  8   Total (charge)                                85108 non-null  object
# ...

# %%
# Importing Libraries
import pandas as pd

# Specify the actual path to your CSV file
csv_file_path = r'C:\Users\User\Desktop\sample\October 8 to October 14\Analyze Data\merged-files.csv'

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(csv_file_path)
df = df.set_index('Customer name (customer)')

# Display the DataFrame
df.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5576\1065695832.py:8: DtypeWarning: Columns (6,7,8,12,16,17,18,19,20,21,27,28,29,30,33,34,35,36,37,38,40,41,42,43,44,48,49,55,57,58,61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path)
#                          Date (charge) Category (charge)  \
# Customer name (customer)
# Cable Rack                  2023-10-09             order
# Cable Rack                  2023-10-09             order
# Cable Rack                  2023-10-09             order
# Cable Rack                  2023-10-10             order
# Cable Rack                  2023-10-10             order
#
#                                    Fee (charge)          Type (charge)  \
# Customer name (customer)
# Cable Rack                Fulfillment - Postage  shipping_label_charge
# Cable Rack                Fulfillment - Postage  shipping_label_charge
# ...

# %%
import pandas as pd
import streamlit as st

# Specify the actual path to your CSV file
csv_file_path = r'C:\Users\User\Desktop\sample\October 8 to October 14\Analyze Data\merged-files.csv'

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(csv_file_path)
df = df.set_index('Customer name (customer)')

# Create a filter for columns
selected_columns = st.multiselect('Select Columns to Display', df.columns)

# Filter the DataFrame based on the selected columns
filtered_df = df[selected_columns]

# Display the filtered DataFrame
st.write(filtered_df)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5576\3420404612.py:8: DtypeWarning: Columns (6,7,8,12,16,17,18,19,20,21,27,28,29,30,33,34,35,36,37,38,40,41,42,43,44,48,49,55,57,58,61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file_path)
# 2023-10-20 14:35:54.499
# ...
#   command:
#
#     streamlit run C:\Users\User\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]
